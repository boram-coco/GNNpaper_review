# %% [raw]
# ---
# title: "Experiment 2"
# author: "김보람"
# date: "03/27/2024"
# ---

# %%
import pandas as pd
import numpy as np
import sklearn
import pickle 
import time 
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
# %run ~/Dropbox/GNNpaper/posts/function_proposed_gcn.py

# %%
with open('./fraudTrain.pkl', 'rb') as file:
    fraudTrain = pickle.load(file)

# %%
merged_df = pd.read_csv('./240326_meged.csv')
merged_df = merged_df[merged_df['model'] != 'WeightedEnsemble_L2']

# %%
merged_df
# Out:
#         model       time       acc       pre       rec        f1       auc  \
# 0        ECOD   0.003704  0.591404  0.003553  0.843750  0.007076  0.717359
# 1         GMM   0.082634  0.692003  0.003410  0.609375  0.006782  0.650760
# 2        HBOS   0.002123  0.936368  0.020868  0.781250  0.040650  0.858943
# 3     IForest   0.144727  0.815358  0.007263  0.781250  0.014393  0.798334
# 4        INNE   0.326223  0.766636  0.005070  0.687500  0.010065  0.727136
# ...       ...        ...       ...       ...       ...       ...       ...
# 1656     LODA   1.380267  0.990775  0.000000  0.000000  0.000000  0.499843
# 1657      LOF   1.171791  0.982414  0.001378  0.001345  0.001361  0.496291
# 1658      MCD   0.101797  0.990787  0.482782  0.471419  0.477033  0.733439
# 1659      PCA   0.029553  0.990787  0.482782  0.471419  0.477033  0.733439
# 1660      ROD  15.238129  0.978524  0.000477  0.000672  0.000558  0.493995
#
# ...

# %%
merged_df = merged_df[(merged_df['pre'] != 0) & (merged_df['rec'] != 0) & (merged_df['f1'] != 0)]

# %%
merged_df.sort_values(by='auc',ascending = False)
# Out:
#                      model      time       acc       pre       rec        f1  \
# 785   LightGBMLarge_BAG_L1       NaN  0.698585  0.000920  1.000000  0.001838
# 838          LightGBMLarge       NaN  0.756869  0.001140  1.000000  0.002278
# 835        NeuralNetFastAI       NaN  0.581460  0.000663  1.000000  0.001325
# 783         XGBoost_BAG_L1       NaN  0.751041  0.001114  1.000000  0.002225
# 829               LightGBM       NaN  0.762698  0.001168  1.000000  0.002334
# ...                    ...       ...       ...       ...       ...       ...
# 177                    PCA  0.002264  0.362902  0.000490  0.209302  0.000978
# 551                    PCA  0.002195  0.382297  0.000375  0.176471  0.000748
# 193                    PCA  0.002498  0.419414  0.000866  0.100000  0.001718
# 1324                   PCA  0.002321  0.230898  0.002240  0.281250  0.004444
# 451                    PCA  0.002268  0.234765  0.238866  0.232283  0.235529
#
# ...

# %%
merged_df.loc[merged_df['model'] == 'GCN', 'model'] = 'Proposed'

# %% [markdown]
# ---

# %%
ex2 = merged_df[merged_df['throw_rate'] ==0.02]

# %%
ex2 = ex2.sort_values(by='auc', ascending = False)

# %%
ex2
# Out:
#                  model         time       acc       pre       rec        f1  \
# 802           Proposed          NaN  0.983310  0.726891  0.235534  0.355784
# 790           LightGBM          NaN  0.984176  0.786913  0.306536  0.441204
# 798     NeuralNetTorch          NaN  0.985867  0.735678  0.478431  0.579802
# 799      LightGBMLarge          NaN  0.979620  0.000000  0.000000  0.000000
# 797            XGBoost          NaN  0.984189  0.785358  0.308497  0.442985
# 793           CatBoost          NaN  0.984136  0.686880  0.407190  0.511284
# 796    NeuralNetFastAI          NaN  0.985375  0.789544  0.384967  0.517575
# 794     ExtraTreesGini          NaN  0.983084  0.613835  0.458170  0.524701
# 795     ExtraTreesEntr          NaN  0.983097  0.613183  0.462092  0.527022
# 791   RandomForestGini          NaN  0.982098  0.578814  0.446405  0.504059
# 792   RandomForestEntr          NaN  0.982098  0.578814  0.446405  0.504059
# ...

# %%
ex2[ex2['model'] == 'GCN']
# Out:
# Empty DataFrame
# Columns: [model, time, acc, pre, rec, f1, auc, graph_based, method, throw_rate, train_size, train_cols, train_frate, test_size, test_frate, hyper_params, theta, gamma]
# Index: []

# %%
ex2_1 = merged_df[merged_df['throw_rate'] ==0.03]

# %%
ex2_1 = ex2_1.sort_values(by='auc', ascending = False)
ex2_1
# Out:
#                  model         time       acc       pre       rec        f1  \
# 801           Proposed          NaN  0.973626  0.660944  0.299029  0.411765
# 65            LightGBM          NaN  0.979900  0.715889  0.550465  0.622372
# 74       LightGBMLarge          NaN  0.969910  0.000000  0.000000  0.000000
# 73      NeuralNetTorch          NaN  0.980719  0.800222  0.478752  0.599086
# 72             XGBoost          NaN  0.979161  0.667632  0.612218  0.638725
# 71     NeuralNetFastAI          NaN  0.980380  0.795045  0.468792  0.589808
# 68            CatBoost          NaN  0.978402  0.711864  0.474104  0.569151
# 69      ExtraTreesGini          NaN  0.978382  0.689964  0.511288  0.587338
# 70      ExtraTreesEntr          NaN  0.978382  0.691682  0.507968  0.585758
# 66    RandomForestGini          NaN  0.977243  0.665167  0.490704  0.564769
# 67    RandomForestEntr          NaN  0.977243  0.665167  0.490704  0.564769
# ...

# %%
ex2_2 = merged_df[merged_df['throw_rate'] ==0.04]

# %%
ex2_2.sort_values(by='auc', ascending = False)
# Out:
#                 model        time       acc       pre       rec        f1  \
# 303          Proposed         NaN  0.972455  0.721095  0.483673  0.578990
# 762          LightGBM         NaN  0.975785  0.802030  0.525266  0.634793
# 770    NeuralNetTorch         NaN  0.977143  0.776541  0.603059  0.678892
# 771     LightGBMLarge         NaN  0.975785  0.802030  0.525266  0.634793
# 765          CatBoost         NaN  0.975598  0.749153  0.587766  0.658718
# 769           XGBoost         NaN  0.976371  0.736398  0.638963  0.684229
# 768   NeuralNetFastAI         NaN  0.974080  0.854473  0.425532  0.568131
# 766    ExtraTreesGini         NaN  0.974133  0.731941  0.559176  0.633999
# 767    ExtraTreesEntr         NaN  0.974053  0.731239  0.557181  0.632453
# 764  RandomForestEntr         NaN  0.972321  0.704485  0.532580  0.606588
# 763  RandomForestGini         NaN  0.972321  0.704485  0.532580  0.606588
# 759    KNeighborsUnif         NaN  0.976397  0.758361  0.603059  0.671852
# ...

# %%
ex2_3 = merged_df[merged_df['throw_rate'] ==0.1]

# %%
ex2_3 = ex2_3.sort_values(by='auc', ascending = False)
ex2_3
# Out:
#                  model  time       acc       pre       rec        f1  \
# 812           Proposed   NaN  0.945721  0.771200  0.645680  0.702880
# 1018          LightGBM   NaN  0.956577  0.879121  0.648649  0.746501
# 1027     LightGBMLarge   NaN  0.956577  0.879121  0.648649  0.746501
# 1026    NeuralNetTorch   NaN  0.957776  0.822901  0.728378  0.772760
# 1025           XGBoost   NaN  0.959041  0.846277  0.714189  0.774643
# 1021          CatBoost   NaN  0.958974  0.845600  0.714189  0.774359
# 1017        LightGBMXT   NaN  0.948452  0.788399  0.652027  0.713757
# 1024   NeuralNetFastAI   NaN  0.955178  0.783556  0.753378  0.768171
# 1023    ExtraTreesEntr   NaN  0.950516  0.789020  0.679730  0.730309
# 1022    ExtraTreesGini   NaN  0.950916  0.790916  0.682432  0.732680
# 1019  RandomForestGini   NaN  0.947186  0.769412  0.662838  0.712160
# 1020  RandomForestEntr   NaN  0.947186  0.769412  0.662838  0.712160
# 1015    KNeighborsUnif   NaN  0.955445  0.823623  0.697297  0.755214
# ...

# %%
ex2_4 = merged_df[(merged_df['throw_rate'] ==0.2) & (merged_df['train_frate'] <= 0.21)]

# %%
ex2_4= ex2_4.sort_values(by='auc', ascending = False)
ex2_4 = ex2_4[ex2_4['train_size'] == 22522]

# %%
ex2_4
# Out:
#                 model  time       acc       pre       rec        f1       auc  \
# 811          Proposed   NaN  0.930075  0.816248  0.840637  0.828263  0.973986
# 487          CatBoost   NaN  0.934070  0.918244  0.727335  0.811715  0.966212
# 484          LightGBM   NaN  0.934204  0.941070  0.707566  0.807782  0.964369
# 493     LightGBMLarge   NaN  0.934204  0.941070  0.707566  0.807782  0.964319
# 491           XGBoost   NaN  0.934070  0.927065  0.719155  0.809981  0.960217
# 492    NeuralNetTorch   NaN  0.935669  0.903941  0.750511  0.820112  0.959982
# 483        LightGBMXT   NaN  0.934070  0.905676  0.739605  0.814259  0.956430
# 488    ExtraTreesGini   NaN  0.919552  0.820341  0.753238  0.785359  0.941221
# 489    ExtraTreesEntr   NaN  0.920485  0.823180  0.755283  0.787771  0.940823
# 485  RandomForestGini   NaN  0.917155  0.813660  0.747103  0.778962  0.934092
# 486  RandomForestEntr   NaN  0.917155  0.813660  0.747103  0.778962  0.934092
# ...

# %%
ex2_5 = merged_df[(merged_df['throw_rate'] ==0.3) & (merged_df['train_frate'] <= 0.31)]

# %%
ex2_5.sort_values(by='auc', ascending = False)
# Out:
#                  model  time       acc       pre       rec        f1  \
# 810           Proposed   NaN  0.936663  0.853101  0.951007  0.899397
# 1211          Proposed   NaN  0.972194  0.650794  0.956667  0.774629
# 1352           XGBoost   NaN  0.907892  0.878903  0.792582  0.833514
# 1345          LightGBM   NaN  0.907892  0.904143  0.764423  0.828433
# 1354     LightGBMLarge   NaN  0.906094  0.896302  0.765797  0.825926
# 1353    NeuralNetTorch   NaN  0.909291  0.929674  0.744505  0.826850
# 1210          Proposed   NaN  0.972028  0.652778  0.940000  0.770492
# 1348          CatBoost   NaN  0.907892  0.929249  0.739698  0.823709
# 1350    ExtraTreesEntr   NaN  0.892707  0.830338  0.793269  0.811380
# 1349    ExtraTreesGini   NaN  0.891309  0.827116  0.791896  0.809123
# 1347  RandomForestEntr   NaN  0.888112  0.821377  0.786401  0.803509
# 1346  RandomForestGini   NaN  0.888112  0.821377  0.786401  0.803509
# 1342    KNeighborsUnif   NaN  0.899700  0.849195  0.796703  0.822112
# ...

# %%
ex2_5 = merged_df[(merged_df['throw_rate'] ==0.3) & (merged_df['train_frate'] <= 0.31)]

# %%
ex2_5.sort_values(by='auc', ascending = False)
# Out:
#                  model  time       acc       pre       rec        f1  \
# 810           Proposed   NaN  0.936663  0.853101  0.951007  0.899397
# 1211          Proposed   NaN  0.972194  0.650794  0.956667  0.774629
# 1352           XGBoost   NaN  0.907892  0.878903  0.792582  0.833514
# 1345          LightGBM   NaN  0.907892  0.904143  0.764423  0.828433
# 1354     LightGBMLarge   NaN  0.906094  0.896302  0.765797  0.825926
# 1353    NeuralNetTorch   NaN  0.909291  0.929674  0.744505  0.826850
# 1210          Proposed   NaN  0.972028  0.652778  0.940000  0.770492
# 1348          CatBoost   NaN  0.907892  0.929249  0.739698  0.823709
# 1350    ExtraTreesEntr   NaN  0.892707  0.830338  0.793269  0.811380
# 1349    ExtraTreesGini   NaN  0.891309  0.827116  0.791896  0.809123
# 1347  RandomForestEntr   NaN  0.888112  0.821377  0.786401  0.803509
# 1346  RandomForestGini   NaN  0.888112  0.821377  0.786401  0.803509
# 1342    KNeighborsUnif   NaN  0.899700  0.849195  0.796703  0.822112
# ...

# %%
ex2_6 = merged_df[(merged_df['throw_rate'] ==0.4) & (merged_df['train_frate'] <= 0.41)]

# %%
ex2_6.sort_values(by='auc', ascending = False)
# Out:
#                 model  time       acc       pre       rec        f1       auc  \
# 809          Proposed   NaN  0.927544  0.881068  0.950262  0.914358  0.964189
# 380          LightGBM   NaN  0.890783  0.881295  0.833333  0.856643  0.959758
# 389     LightGBMLarge   NaN  0.889185  0.906009  0.800000  0.849711  0.957676
# 388    NeuralNetTorch   NaN  0.891050  0.898573  0.813605  0.853981  0.957354
# 387           XGBoost   NaN  0.891050  0.861130  0.860544  0.860837  0.957299
# 383          CatBoost   NaN  0.890783  0.908951  0.801361  0.851772  0.956197
# 385    ExtraTreesEntr   NaN  0.864678  0.824124  0.831973  0.828030  0.941670
# 384    ExtraTreesGini   NaN  0.863612  0.823649  0.829252  0.826441  0.940610
# 377    KNeighborsUnif   NaN  0.880661  0.859353  0.831293  0.845090  0.936374
# 381  RandomForestGini   NaN  0.859883  0.818919  0.824490  0.821695  0.936301
# 382  RandomForestEntr   NaN  0.859883  0.818919  0.824490  0.821695  0.936301
# ...

# %%
ex2_7 = merged_df[(merged_df['throw_rate'] ==0.5) & (merged_df['train_frate'] <= 0.51)]

# %%
ex2_7.sort_values(by='auc', ascending = False)
# Out:
#          model      time       acc       pre       rec        f1       auc  \
# 1188  Proposed       NaN  0.967250  0.972487  0.961688  0.967058  0.987065
# 1189  Proposed       NaN  0.965307  0.965039  0.965575  0.965307  0.986926
# 643   Proposed       NaN  0.966034  0.963887  0.968977  0.966425  0.985536
# 1190  Proposed       NaN  0.963364  0.963354  0.963354  0.963354  0.984985
# 642   Proposed       NaN  0.955045  0.953083  0.956288  0.954683  0.978829
# ...        ...       ...       ...       ...       ...       ...       ...
# 447        LOF  0.016555  0.505495  0.511684  0.560367  0.534920  0.504660
# 446       LODA  0.023346  0.492507  0.000000  0.000000  0.000000  0.500000
# 441       HBOS  0.897164  0.492174  0.000000  0.000000  0.000000  0.499662
# 452        ROD  2.136653  0.318015  0.324161  0.316929  0.320504  0.318032
# 451        PCA  0.002268  0.234765  0.238866  0.232283  0.235529  0.234803
#
# ...

# %%
ex2_77 = ex2_7[ex2_7['model'] != 'GCN'].sort_values(by='auc', ascending = False)
ex2_77
# Out:
#          model      time       acc       pre       rec        f1       auc  \
# 1188  Proposed       NaN  0.967250  0.972487  0.961688  0.967058  0.987065
# 1189  Proposed       NaN  0.965307  0.965039  0.965575  0.965307  0.986926
# 643   Proposed       NaN  0.966034  0.963887  0.968977  0.966425  0.985536
# 1190  Proposed       NaN  0.963364  0.963354  0.963354  0.963354  0.984985
# 642   Proposed       NaN  0.955045  0.953083  0.956288  0.954683  0.978829
# ...        ...       ...       ...       ...       ...       ...       ...
# 447        LOF  0.016555  0.505495  0.511684  0.560367  0.534920  0.504660
# 446       LODA  0.023346  0.492507  0.000000  0.000000  0.000000  0.500000
# 441       HBOS  0.897164  0.492174  0.000000  0.000000  0.000000  0.499662
# 452        ROD  2.136653  0.318015  0.324161  0.316929  0.320504  0.318032
# 451        PCA  0.002268  0.234765  0.238866  0.232283  0.235529  0.234803
#
# ...

# %%
ex2_777 = ex2_7[ex2_7.theta == 1e+7][-1:]

# %%
ex2_8 = pd.concat([ex2_77, ex2_777])

# %%
ex2_8 = ex2_8.sort_values(by='auc', ascending = False)
ex2_8
# Out:
#          model      time       acc       pre       rec        f1       auc  \
# 1188  Proposed       NaN  0.967250  0.972487  0.961688  0.967058  0.987065
# 1189  Proposed       NaN  0.965307  0.965039  0.965575  0.965307  0.986926
# 643   Proposed       NaN  0.966034  0.963887  0.968977  0.966425  0.985536
# 1190  Proposed       NaN  0.963364  0.963354  0.963354  0.963354  0.984985
# 642   Proposed       NaN  0.955045  0.953083  0.956288  0.954683  0.978829
# ...        ...       ...       ...       ...       ...       ...       ...
# 447        LOF  0.016555  0.505495  0.511684  0.560367  0.534920  0.504660
# 446       LODA  0.023346  0.492507  0.000000  0.000000  0.000000  0.500000
# 441       HBOS  0.897164  0.492174  0.000000  0.000000  0.000000  0.499662
# 452        ROD  2.136653  0.318015  0.324161  0.316929  0.320504  0.318032
# 451        PCA  0.002268  0.234765  0.238866  0.232283  0.235529  0.234803
#
# ...

# %%
max_auc_df = ex2_8.groupby('model')['auc'].max().reset_index()
filtered_df = pd.merge(ex2_8, max_auc_df, how='inner', on=['model', 'auc'])
ex2_8 = filtered_df.sort_values(by='auc', ascending=False)

# %%
ex2_8
# Out:
#                       model      time       acc       pre       rec        f1  \
# 0                  Proposed       NaN  0.967250  0.972487  0.961688  0.967058
# 1            XGBoost_BAG_L1       NaN  0.889536  0.904789  0.870627  0.887380
# 2           LightGBM_BAG_L1       NaN  0.889536  0.903857  0.871738  0.887507
# 3                   XGBoost       NaN  0.883783  0.900273  0.866535  0.883082
# 4      LightGBMLarge_BAG_L1       NaN  0.887594  0.903002  0.868406  0.885367
# 5                  LightGBM       NaN  0.887446  0.904306  0.869822  0.886729
# 6             LightGBMLarge       NaN  0.883153  0.900697  0.861188  0.880500
# 7           CatBoost_BAG_L1       NaN  0.886761  0.901904  0.867851  0.884550
# 8            ExtraTreesEntr       NaN  0.881119  0.901934  0.858646  0.879757
# 9            ExtraTreesGini       NaN  0.883117  0.904006  0.860618  0.881778
# 10                 CatBoost       NaN  0.885651  0.904956  0.861743  0.882821
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Bar(
    x=ex2[0:9]['model'],
    y=ex2[0:9]['auc'],
    name='ratio 0.02',
    marker_color='Coral'
))
fig.add_trace(go.Bar(
    x=ex2_1[ex2_1['model'].isin(ex2[0:9]['model'])]['model'],
    y=ex2_1[ex2_1['model'].isin(ex2[0:9]['model'])]['auc'],
    name='ratio 0.03',
    marker_color='LightGreen'
))
fig.add_trace(go.Bar(
    x=ex2_3[ex2_3['model'].isin(ex2[0:9]['model'])]['model'],
    y=ex2_3[ex2_3['model'].isin(ex2[0:9]['model'])]['auc'],
    name='ratio 0.1',
    marker_color='DodgerBlue'
))
fig.add_trace(go.Bar(
    x=ex2_4[ex2_4['model'].isin(ex2[0:9]['model'])]['model'],
    y=ex2_4[ex2_4['model'].isin(ex2[0:9]['model'])]['auc'],
    name='ratio 0.2',
    marker_color='red'
))
fig.add_trace(go.Bar(
    x=ex2_8[ex2_8['model'].isin(ex2[0:9]['model'])]['model'],
    y=ex2_8[ex2_8['model'].isin(ex2[0:9]['model'])]['auc'],
    name='ratio 0.5',
    marker_color='green'
))

fig.update_layout(barmode='group', xaxis_tickangle=0)

fig.show()

# %% [markdown]
# ---
